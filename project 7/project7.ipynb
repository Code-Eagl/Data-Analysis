# %% [markdown]
# # working on 'Udmey Courses Dataset'

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Data analysis project\7. Udemy Courses.csv")

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %% [markdown]
# # What are alll different subjects for which Udemy is offering courses?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# # Which subject has the maximum number of courses?

# %%
data.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# # Show all the courseswhich are free of cost

# %%
data[data.is_paid ==False].head(2)
# Out:
#     course_id                                       course_title  is_paid  \
# 41     286070        5 lecciones que todo guitarrista debe tomar    False
# 49     696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
#
#    price  num_subscribers  num_reviews  num_lectures           level  \
# 41  Free             4452          263            14  Beginner Level
# 49  Free             4529          193             7  Beginner Level
#
#    content_duration   published_timestamp              subject
# 41           1 hour  2014-08-23T05:08:14Z  Musical Instruments
# 49          36 mins  2015-12-21T18:50:50Z  Musical Instruments

# %% [markdown]
# # Which are Iop Selling Course?

# %%
data.sort_values('num_subscribers',ascending=False).head(2)
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
# 776       59014        Coding for Entrepreneurs Basic    False  Free
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 2230           268923         8629            45      All Levels
# 776            161029          279            27  Beginner Level
#
#      content_duration   published_timestamp          subject
# 2230       10.5 hours  2013-02-14T07:03:41Z  Web Development
# 776         3.5 hours  2013-06-09T15:51:55Z  Web Development

# %% [markdown]
# # Which are Least Selling Courses?

# %%
data.sort_values('num_subscribers',ascending=True).head(2)
# Out:
#       course_id                               course_title  is_paid price  \
# 649     1233314              Building a Balanced Scorecard     True    50
# 3259    1232282  The Cash Flow Statement - An Introduction     True    50
#
#       num_subscribers  num_reviews  num_lectures               level  \
# 649                 0            0            11  Intermediate Level
# 3259                0            0            10      Beginner Level
#
#      content_duration   published_timestamp           subject
# 649           2 hours  2017-07-03T21:38:22Z  Business Finance
# 3259        1.5 hours  2017-06-28T16:05:51Z  Business Finance

# %% [markdown]
# # Show all the courses of Graphic Design Where the price is below 100?

# %%
data[(data.subject == 'Graphic Design')&(data.price <'100')]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
data[(data.subject == 'Graphic Design')&(data.price == '100')].head(2)
# Out:
#      course_id                                  course_title  is_paid price  \
# 47     1269190     7 Secrets To Designing In Black and White     True   100
# 169     983444  Adobe Illustrator Vectors For Hand Letterers     True   100
#
#      num_subscribers  num_reviews  num_lectures           level  \
# 47              1000            1            12      All Levels
# 169               23            2             9  Beginner Level
#
#     content_duration   published_timestamp         subject
# 47         1.5 hours  2017-06-27T19:55:18Z  Graphic Design
# 169          37 mins  2016-10-21T18:50:38Z  Graphic Design

# %%
data[(data.subject == 'Graphic Design')&(data.price >'100')].head(2)
# Out:
#     course_id                                       course_title  is_paid  \
# 8      206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20    1165268  15  Motion Graphic Elements in After Effect (S...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 8     25               72            5            17      Beginner Level
# 20    30                8            0            20  Intermediate Level
#
#    content_duration   published_timestamp         subject
# 8            1 hour  2014-04-29T19:50:31Z  Graphic Design
# 20          3 hours  2017-04-11T04:27:34Z  Graphic Design

# %% [markdown]
# # List out all the courses that are related withPython?

# %%
len(data[data.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# # What are courses that published in year2015?

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data['published_timestamp']=pd.to_datetime(data.published_timestamp)

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['year']= data['published_timestamp'].dt.year

# %%
data.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
#
#   content_duration       published_timestamp              subject  year
# 0        1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments  2014
# 1           1 hour 2017-04-12 19:06:34+00:00  Musical Instruments  2017
# 2        1.5 hours 2017-04-26 18:34:57+00:00  Musical Instruments  2017

# %%
data[data.year ==2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %% [markdown]
# # What are the Max number of subscribersfor Each level of courses?

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
data.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
# ...
