# %% [markdown]
# # project  3

# %% [markdown]
# police dataset
#
# The data is from Police Check post

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Data analysis project\3. Police Data.csv")

# %%
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# # instructions for data cleaning

# %% [markdown]
# # 1 Remove the column that only contain missing values

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
data.drop(columns="country_name", inplace=True)
data.drop(columns="search_type", inplace=True)

# %%
data["driver_age"].fillna(data["driver_age"].mean(), inplace =True)

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# driver_gender          4061
# driver_age_raw         4054
# driver_age                0
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# # question on filturing and data count

# %% [markdown]
# # 2  For Speeding, were Men and Women stopped ore often?

# %%
# speeding is reelated to violation column
# men and women related to gender column

# %%
#to find records containg speeding record
data[data.violation == 'Speeding']
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# ...          ...       ...           ...             ...         ...
# 65527  12/6/2012     15:26             F          1981.0        31.0
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted stop_outcome  \
# ...

# %%
data[data.violation == 'Speeding'].driver_gender.value_counts()
# this shows that men has violeted more then femele
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# # question on Grupby

# %% [markdown]
# # 3 Does gender affect who gets searched during a stop

# %%
data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
data.search_conducted.value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# # Question bsed on mapping and data-type casting

# %% [markdown]
# # 4 what is the mean stop_duration

# %%
data.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
#stop_duration has type of string so to find mean we have to change its data type
data['stop_duration']=data['stop_duration'].map({'0-15 Min' :7.5, '16-30 Min ':23, '30+ Min ':45 })

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0   20.000000
# 1      1/18/2005      8:15             M          1965.0   40.000000
# 2      1/23/2005     23:15             M          1972.0   33.000000
# 3      2/20/2005     17:15             M          1986.0   19.000000
# 4      3/14/2005     10:00             F          1984.0   21.000000
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0   25.000000
# 65531  12/6/2012     22:22             M          1954.0   58.000000
# 65532  12/6/2012     23:20             M          1985.0   27.000000
# 65533  12/7/2012      0:23           NaN             NaN   34.148984
# 65534  12/7/2012      0:30             F          1985.0   27.000000
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
data['stop_duration'].mean()
# Out:
# 7.5

# %% [markdown]
# # question on Groupby,  describe

# %% [markdown]
# #  5  Compare the age of distribution for each violation

# %%
data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6516.0  31.686363  11.373176  16.0  23.0  28.0  39.0
# Moving violation     11926.0  36.725595  13.231582  15.0  25.0  35.0  46.0
# Other                 3583.0  40.178563  12.608331  16.0  30.0  40.0  49.5
# Registration/plates   2243.0  32.658692  11.143450  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37204.0  33.264582  12.601601  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
